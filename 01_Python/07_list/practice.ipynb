# %% [markdown]
# # What is a Data Structure?
#
# A Data Structure is a way of organizing and storing data so that it can be accessed and modified efficiently.
#
# ```
# Intuition
#
# Suppose you have 500 student names.
#
# Storing them like this:
#
# student1 = "Rahul"
# student2 = "Aman"
# student3 = "Riya"
#
# is not practical.
#
# We need a way to store multiple values together.
#
# That is why data structures exist.
# ```

# %% [markdown]
# # List
#
# List is an ordered collection of multiple items stored in a single variable.
#
# 1. A collection means multiple values stored together.
# 2. Ordered means every element has a fixed position.
# 3. It is mutable. -> we can modify its elements after it has been formed.
# 4. Allow duplicates.

# %% [markdown]
# ## Why Do We Need Lists?
#
# ```
# Without lists:
#
# subject1 = "Python"
# subject2 = "DSA"
# subject3 = "DBMS"
# subject4 = "OS"
# subject5 = "CN"
#
# With a list:
#
# subjects = ["Python", "DSA", "DBMS", "OS", "CN"]

# %% [markdown]
# ```
# *********************************************************
#                         question 1
# Is a List a collection data type?
#
# Answer:
# Yes.
# ********************************************************

# %%
" Example 1 "

subject = ["python", "dsa", "dbms"]
subject
# Out:
# ['python', 'dsa', 'dbms']

# %%
print(type(subject))
# Out:
# <class 'list'>

# %% [markdown]
# ## Indexing on lists
#
# Indexing is the process of accessing individual elements of a list using their position number.

# %%
" Example 1 "

fruits = ["Apple", "mango", "banana"]

fruits[0]
# Out:
# 'Apple'

# %% [markdown]
# ```
# ********************************************************
#                 Question 2.
# Why Does Indexing Start From 0?
# Answer:-
#
# Python follows zero-based indexing because it matches how memory locations and offsets are calculated internally.

# %% [markdown]
# ## negative indexing
# Negative indexing starts from the end of the list.

# %%
" Example 1 "

fruits = ["Apple", "mango", "banana"]

fruits[-1]
# Out:
# 'banana'

# %% [markdown]
# ## slicing on list
#
# Slicing is used to access a portion (sublist) of a list.
#
# Instead of getting a single element, slicing returns multiple elements.

# %% [markdown]
# ### Syntax
#
# ```
# list_name[start : stop:jump]
#
# 1. start → Included
# 2. stop → Excluded

# %%
" Exampple 1 "


num = [10,20,30,40]
num[1:3]
# Out:
# [20, 30]

# %%
" Example 2"


nums = [10, 20, 30, 40, 50]

print(nums[-3:])
# Out:
# [30, 40, 50]

# %%
" Example 3 "

nums = [10, 20, 30, 40, 50, 60]

print(nums[::2])
# Out:
# [10, 30, 50]

# %%
" Example 4"

nums = [10, 20, 30, 40, 50,60]

print(nums[::-1])
# Out:
# [60, 50, 40, 30, 20, 10]

# %% [markdown]
# ## list methods

# %% [markdown]
# ### 1) append()
# The append() method is used to add a single element at the end of a list.

# %% [markdown]
# #### Syntax
# ```
# list_name.append(element)

# %%
" Example 1 "

nums = [10, 20]

result = nums.append(30)

print(result)
# Out:
# None

# %% [markdown]
# ```
# **************************************************************
#  why None?
#
#
# append() modifies the original list and returns None.

# %%
" Example 1 "

nums = [10, 20]

nums.append(30)

nums
# Out:
# [10, 20, 30]

# %%
" Example 2 "

a = [1,2]

a.append([3,4])
a
# Out:
# [1, 2, [3, 4]]

# %%
" Example 3 "

b = [5,6]
print(b.append(3))
# Out:
# None

# %% [markdown]
# ### 2) extend()
# The extend() method is used to add multiple elements from an iterable to the end of a list.

# %% [markdown]
# ### Syntax
# ```
# list_name.extend(iterable)

# %%
" Example 1 "


nums = [1,2]

nums.extend([4,5,6])
nums
# Out:
# [1, 2, 4, 5, 6]

# %%
" Example 2 "

num = [3,4]

""" extend() works with any iterable."""

""" 1) List"""

num.extend([5,6])

print("iterable was list:",num)

""" 2) tuple """
num.extend((7,8))
print("itrable was tuple: ",num)

""" 3) string """
 
num.extend("ABCD")
print("iterable was string: ",num)
# Out:
# iterable was list: [3, 4, 5, 6]
# itrable was tuple:  [3, 4, 5, 6, 7, 8]
# iterable was string:  [3, 4, 5, 6, 7, 8, 'A', 'B', 'C', 'D']

# %% [markdown]
# ```
# ***************************************************************
#                             Question 1.
# Does extend() return a new list?
#
# No.
#
# It modifies the original list and returns None.
# ****************************************************************

# %%
" Example 3 "

fruit = ["apple"]

fruit.extend("banana")
fruit
# Out:
# ['apple', 'b', 'a', 'n', 'a', 'n', 'a']

# %%
" Example 4 "

text1 = ["data"]
text2 = ["science"]

text1.extend(text2)
print(text1)
print(text2)
# Out:
# ['data', 'science']
# ['science']

# %% [markdown]
# ### 3) insert()
#
# The insert() method is used to add an element at a specific position (index) in a list.

# %% [markdown]
# ```
# Syntax
#
# list_name.insert(index, element)

# %%
" Example 1 "

num = [10,20,30]

num.insert(2, 1000)
num
# Out:
# [10, 20, 1000, 30]

# %%
"Example 2 "

num.insert(100, "01")
num
# Out:
# [10, 20, 1000, 30, '01']

# %% [markdown]
# ```
# ********************************
#         Question 1
#  Does insert() return a new list?
#
# No.
#
# It modifies the original list and returns None.
# ************************************

# %%
" Example 3"

nums = [10, 20]

nums.insert(-1, 15)

print(nums)
print('insert(-1, x) means insert before the last element, not replace it.')
# Out:
# [10, 15, 20]
# insert(-1, x) means insert before the last element, not replace it.

# %% [markdown]
# ```
# Explanantion:-
# insert(-1, x) means insert before the last element, not replace it.

# %%
" Example 4 "

l1 = [1,2,3]
l2 = [6,7,8]
l1.insert(1, l2)
l1
# Out:
# [1, [6, 7, 8], 2, 3]

# %% [markdown]
# ### 4. remove()
# The remove() method is used to remove the first occurrence of a specified value from a list.

# %% [markdown]
# ```
# syntax
#
# list_name.remove(value)

# %%
"Example 1"

nums = [10,20,30]

nums.remove(20)
nums
# Out:
# [10, 30]

# %%
print(nums)
# Out:
# [10, 30]

# %% [markdown]
# ```
# **********************************************
# Important Point
#
# remove() removes by value, not by index.
# **********************************************

# %%
"Example 2"

nums = [10,20,30,40,20,50]
print(nums)
nums.remove(20)
print(nums)
# Out:
# [10, 20, 30, 40, 20, 50]
# [10, 30, 40, 20, 50]

# %%
nums.remove(60)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 nums.remove(60)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ```
# "***************************************************************"
#
# Does remove() return a new list?
# No.
# It modifies the original list and returns None.
#
# *****************************************************************

# %% [markdown]
# ### 5. pop()
#
# The pop() method is used to remove last element and return an element from a list.
#
# 1. By default pop() removes the last index.

# %% [markdown]
# ```
# Syntax:-
#
# Remove Last Element -> list_name.pop()
#
# Remove Element at Specific Index -> list_name.pop(index)

# %%
" Example 1"


nums = [10,20,30]
nums.pop()
# Out:
# 30

# %%
print(nums)
# Out:
# [10, 20]

# %%
" Example 2"

nums = [10,20,30,40,50]
nums.pop(1)
print(nums)
# Out:
# [10, 30, 40, 50]

# %%
"Example 3"

num = [10,20,30]

res = num.pop()
res
# Out:
# 30

# %% [markdown]
# ```
#
# pop() returns the removed value.
#
# ```

# %%
" Example 4"

num = [1,2]
num.pop(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 " Example 4"
#       3 num = [1,2]
# ----> 4 num.pop(3)
#
# IndexError: pop index out of range

# %% [markdown]
# ### 6. clear()
#
# The clear() method is used to remove all elements from a list.

# %%
" Example 1"

nums = [10, 20, 30]

nums.clear()

print(nums)
# Out:
# []

# %%
print(nums)
# Out:
# []

# %% [markdown]
# ```
# ************************************************
#
# Important Point
#
# clear() does not delete the list variable, it  deletes all the elements.
#
# What does clear() return?
# None
#
# *************************************************

# %% [markdown]
# ### 7. count()
#
# The count() method is used to count how many times a specified value appears in a list.

# %% [markdown]
# ```
# Syntax:-
#
# list_name.count(value)

# %%
"Example 1"

nums = [10, 20, 10, 30, 10]

print(nums.count(10))
# Out:
# 3

# %%
"Example 2"


fruits = ["Apple", "Banana", "mango", "strawberry", "mango", "mango", "banana", "banana"]
print(fruits)
fruits.count("mango")
# Out:
# ['Apple', 'Banana', 'mango', 'strawberry', 'mango', 'mango', 'banana', 'banana']
# 3

# %%
print(fruits)
res = fruits.count("banana")

print(res)
# Out:
# ['Apple', 'Banana', 'mango', 'strawberry', 'mango', 'mango', 'banana', 'banana']
# 2

# %% [markdown]
# ```
# ***********************************************
#
# Return Value
#
# count() returns an intege
#
# ***********************************************

# %% [markdown]
# ### 8. max()
#
# The max() function is used to find the largest element in an iterable (such as a list, tuple, string, etc.).

# %% [markdown]
# ```
# Syntax:-
#
# max(iterable)

# %%
"Example 1"

nums = [10, 50, 20, 30]

print(max(nums))
# Out:
# 50

# %%
" Example 2"

fruits = ["apple", "Mango", "banana"]

print(max(fruits))
# Out:
# banana

# %% [markdown]
# ```
# *************************************************
#
# Python compares strings alphabetically (ASCII).
#
# ************************************************

# %%
" Example 3"

a = [1,2,3, "A","B"]
max(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 " Example 3"
#       3 a = [1,2,3, "A","B"]
# ----> 4 max(a)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### 9. min()
#
# The min() function is used to find the smallest element in an iterable (list, tuple, string, etc.).

# %%
"Example 1"

nums = [10, 50, 20, 30]

print(min(nums))
# Out:
# 10

# %%
"Example 2"

fruits = ["apple", "mango", "banana"]

print(min(fruits))
# Out:
# apple

# %%
"Example 3"

" Example 3"

a = [1,2,3, "A","B"]
min(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 " Example 3"
#       5 a = [1,2,3, "A","B"]
# ----> 6 min(a)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# ### 10. sort()
#
# The sort() method is used to sort the elements of a list in ascending order by default.

# %% [markdown]
# ```
# Syntax
#
# list_name.sort()

# %%
"Example 1"

nums = [50, 10, 30, 20]

nums.sort()

print(nums)
# Out:
# [10, 20, 30, 50]

# %% [markdown]
# ```
# ********************************************
#
# Important Point
#
# sort() modifies the original list.
#
# ********************************************

# %%
"Example 2"

nums = [50, 10, 30, 20]

nums.sort(reverse=True)

print(nums)
# Out:
# [50, 30, 20, 10]

# %%
"Example 3"

fruits = ["mango", "apple", "banana"]

fruits.sort()

print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# ```
# ************************************
#
# Alphabetical (ASCII) order.
#
# ***********************************

# %%
"Example 4"


fruits = ["apple", "Apple", "Banana"]

fruits.sort()

print(fruits)
# Out:
# ['Apple', 'Banana', 'apple']

# %% [markdown]
# ```
# *********************************
#
# Return Value
#
# None
#
# *********************************

# %% [markdown]
# ### 11. reverse()
# The reverse() method is used to reverse the order of elements in a list.

# %%
"Example 1"

nums = [10, 20, 30, 40]

nums.reverse()

print(nums)
# Out:
# [40, 30, 20, 10]

# %% [markdown]
# ```
# *****************************************
# Important Point
#
# reverse() does not sort the list.
#
# It only reverses the current order.
# *******************************************

# %%
"Example 2"

nums = [30, 10, 20]

nums.reverse()

print(nums)
# Out:
# [20, 10, 30]

# %%
"Example 3"

fruits = ["apple", "banana", "mango"]

res = fruits.reverse()
print(res)
# Out:
# None

# %% [markdown]
# ### 12. index()
# Gives you index of first occurence of  specified element.

# %%
"Example 1"

fruits = ["apple", "banana","apple", "mango"]
fruits.index("apple")
# Out:
# 0

# %% [markdown]
# ### 13. copy()
#
# The copy() method is used to create a shallow copy of a list.
#
# returns a new list without modifying the original lists.

# %%
"Example 1"


num1 = [1,2,3,4,5]
num2 = num1.copy()

print("num1",num1)
print("num2",num2)
# Out:
# num1 [1, 2, 3, 4, 5]
# num2 [1, 2, 3, 4, 5]

# %%
num1[0] = 101

print("num1",num1)
print("num2",num2)
# Out:
# num1 [101, 2, 3, 4, 5]
# num2 [1, 2, 3, 4, 5]

# %%
num2[0] = 100
print("num1",num1)
print("num2",num2)
# Out:
# num1 [1, 2, 3, 4, 5]
# num2 [100, 2, 3, 4, 5]

# %% [markdown]
# ### 14. deep copy

# %%
"Example 1"

num = [1,2,3,4,5]

num1 = num

print("num",num)
print("num1",num1)
# Out:
# num [1, 2, 3, 4, 5]
# num1 [1, 2, 3, 4, 5]

# %%
num[0] = "hello"
print("num",num)
print("num1",num1)
# Out:
# num ['hello', 2, 3, 4, 5]
# num1 ['hello', 2, 3, 4, 5]

# %% [markdown]
# ```
# ******************************************
# num ----┐
#       ├──> [10,20,30]
# num1----┘
#
# Both variables point to the same list.
#
# ******************************************
