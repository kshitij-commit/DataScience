# %% [markdown]
# # Conditions

# %% [markdown]
# ## 1) If condition
# The if statement is used to execute a block of code only when a condition is True.

# %% [markdown]
# ```
# Syntax
#
# if condition:
#     statement
# ```

# %%
age = int(input("Enter your age: "))

if age>=18:
    print("Eligible for vote.")
else:
    print("Not eligible for vote.")
# Out:
# Eligible for votes.

# %%
"""Take two numbers from user and print the greater one."""
# Out:
# 'Take two numbers from user and print the greater one.'

# %%
"""Example 2"""


num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1>num2:
    print(f"{num1} is greater than {num2}.")
if num2>num1:
    print(f"{num2} is greater than {num1}.")
if num1 == num2:
    print(f"{num1} and {num2} is equal.")
# Out:
# 21 and 21 is equal.

# %% [markdown]
# ## 2) if-else
#
# The if-else statement executes one block of code when the condition is True and another block when the condition is False

# %% [markdown]
# ```
# Syntax
#
# if condition:
#     statement1
# else:
#     statement2
#
# ```

# %%
age = 20

if age >= 18:
    print("eligible for vote.")
else:
    print("Not eligible for vote.")
# Out:
# eligible for vote.

# %% [markdown]
# ## 3) if-elif-else condition
# elif is used to check multiple conditions after an if statement.

# %% [markdown]
# ```
# Syntax
# if condition1:
#     statement1
#
# elif condition2:
#     statement2
#
# elif condition3:
#     statement3
#
# else:
#     statement4
# ```

# %%
"""Example 1"""


marks = int(input("Enter your marks: "))

if marks >= 95:
    print("Grade O+")
elif marks >=85:
    print("Grade A+")
elif marks >= 75:
    print("Grade A")
elif marks>=65:
    print("Grade B+")
else:
    print("Fail")
# Out:
# Grade B+

# %% [markdown]
# ```
# Can elif exist without if?
#
# No.
# ```

# %% [markdown]
# ## 4) Nested if
# A nested if is an if statement placed inside another if statement.
#
# One condition is checked first, and if it is True, another condition is checked inside it.

# %% [markdown]
# ```
# Syntax
# if condition1:
#     if condition2:
#         statement
#
# Notice:
#
# Second if is inside the first if
# Indentation becomes very important
# ```

# %%
""" Example 1 """


""" Enter the value from user, and check is it greater then 10 or 20 and not   """
# Out:
# ' Enter the value from user, and check is it greater then 10 or 20 and not   '

# %%
"""Example 1"""


num = int (input("Enter the number"))

if num > 10:
    if num > 20:
        print("greater then 20.")
    else:
        print("Number is greater than 10.")
else:
    print("Number is less than 10.")
# Out:
# Number is greater than 10.
