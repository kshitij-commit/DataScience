# %% [markdown]
# # Dictionary
#
# A Dictionary is a mutable collection of key-value pairs.
#
# Characteristics:-
# 1. Mutable
# 2. No Indexing
# 3. Keys can't be duplicated
# 4. Keys can't be mutable items.
#
# A dictionary stores data as:
#
# key : value

# %% [markdown]
# Dictionaries do not support numeric/positional indexing. Data is accessed using keys.

# %% [markdown]
# ## 1. Properties of Dictionary

# %% [markdown]
# ### 1. Mutable

# %%
"Example 1"

dict = {"Name":"Nitish", "Age":33, "gender":"Male"}
dict
# Out:
# {'Name': 'Nitish', 'Age': 33, 'gender': 'Male'}

# %%
dict["Name"]  = "rossom"
dict
# Out:
# {'Name': 'rossom', 'Age': 33, 'gender': 'Male'}

# %% [markdown]
# ### 2.Keys Must Be Unique

# %%
"Example 1"

d = {
    "name": "A",
    "name": "B" 
}



print(d)
# Out:
# {'name': 'B'}

# %%
""" the last value wins"""
# Out:
# ' the last value wins'
