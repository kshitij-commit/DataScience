# %%
import pandas as pd

# %%
import pandas as pd

# %%
df = pd.read_csv("free-taxonomy.csv")
df.head(3)
# Out:
#         name    id parent_name  parent_id                       vocabulary  \
# 0  Emergency  1101           0        0.0  Open Eligibility Human Services
# 1       Food  1102           0        0.0  Open Eligibility Human Services
# 2    Housing  1103           0        0.0  Open Eligibility Human Services
#
#                                        x-description x-notes  services
# 0  Services for psychiatric emergencies, emergenc...     NaN       NaN
# 1  Services for free meals, food pantries, help p...     NaN       NaN
# 2  Services for emergency, short-term and long-te...     NaN       NaN

# %%
df
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %% [markdown]
# # 1.drop missing values

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [name, id, parent_name, parent_id, vocabulary, x-description, x-notes, services]
# Index: []

# %%
df
# Out:
#                         name     id parent_name  parent_id  \
# 0                  Emergency   1101           0        0.0
# 1                       Food   1102           0        0.0
# 2                    Housing   1103           0        0.0
# 3                      Goods   1104           0        0.0
# 4                    Transit   1105           0        0.0
# ..                       ...    ...         ...        ...
# 322                In Danger  20089     Urgency    20087.0
# 323          Chronic Illness  20090      Health     1106.0
# 324                  Spouses  20091        Role    20072.0
# 325               Dependents  20092        Role    20072.0
# 326  Intellectual Disability  20093  Disability    20017.0
#
#                             vocabulary  \
# 0      Open Eligibility Human Services
# 1      Open Eligibility Human Services
# 2      Open Eligibility Human Services
# 3      Open Eligibility Human Services
# 4      Open Eligibility Human Services
# ...

# %%
df.columns
# Out:
# Index(['name', 'id', 'parent_name', 'parent_id', 'vocabulary', 'x-description',
#        'x-notes', 'services'],
#       dtype='object')

# %%
df["parent_name"].tail(20)
# Out:
# 307          Role
# 308          Role
# 309          Role
# 310           NaN
# 311     Sexuality
# 312           NaN
# 313     Survivors
# 314     Survivors
# 315     Survivors
# 316     Survivors
# 317     Survivors
# 318     Survivors
# 319     Survivors
# 320           NaN
# 321       Urgency
# 322       Urgency
# 323        Health
# 324          Role
# 325          Role
# 326    Disability
# Name: parent_name, dtype: object

# %% [markdown]
# ## 1.1 drop missing values based on  columns

# %%
df.dropna(axis=1,inplace=True)

# %%
df
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]

# %% [markdown]
# ## 1.1 drop missing values based on rows.

# %%
df.dropna(axis=0)
# Out:
#                         name     id                         vocabulary
# 0                  Emergency   1101    Open Eligibility Human Services
# 1                       Food   1102    Open Eligibility Human Services
# 2                    Housing   1103    Open Eligibility Human Services
# 3                      Goods   1104    Open Eligibility Human Services
# 4                    Transit   1105    Open Eligibility Human Services
# ..                       ...    ...                                ...
# 322                In Danger  20089  Open Eligibility Human Situations
# 323          Chronic Illness  20090  Open Eligibility Human Situations
# 324                  Spouses  20091  Open Eligibility Human Situations
# 325               Dependents  20092  Open Eligibility Human Situations
# 326  Intellectual Disability  20093  Open Eligibility Human Situations
#
# [327 rows x 3 columns]
