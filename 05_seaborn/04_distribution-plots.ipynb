# %% [markdown]
# # 1. histplot

# %% [markdown]
# Used for numerical data.
#
# - Used to visualize the distribution of numerical data.
# - Groups data into intervals called bins.
# - The height of each bar represents the frequency (count) of observations in that bin.
#
# - Bar height = Frequency (Count).
# - Bars touch each other because the data is continuous.

# %% [markdown]
# It helps answer questions like:
#
# - Where are most values concentrated?
# - Is the data normally distributed?
# - Is the data left-skewed or right-skewed?
# - Are there multiple peaks?
# - Are there possible outliers?

# %% [markdown]
# ```
# sns.histplot(
#     data=tips,
#     x='total_bill'
# )
# ```

# %%
import seaborn as sns

# %%
tips = sns.load_dataset(
    'tips'

)

# %%
sns.histplot(
    data = tips,
    x = 'total_bill'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ```
# Around 48 customer have bill between 12-15.
# ```

# %% [markdown]
# ## 1.1 bins

# %% [markdown]
# ```
# 5-10
# 10-15
# 15-20
# 20-25
# 25-30
# ```
# These ranges are called bins.
#
# One bar = One bin (range).

# %% [markdown]
# bins=10
#
# means:
#
# Divide the data into 10 intervals (10 bars).

# %% [markdown]
# - Bins are intervals (ranges) used to group numerical data.
# - One bar represents one bin.
# - More bins → More bars → More detail.
# - Fewer bins → Wider bars → Less detail.
# - Changing bins changes only the visualization, not the data.

# %%
sns.histplot(
    data = tips,
    x = 'tip',
    bins = 15
)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(
    data = tips,
    x = 'total_bill',
    bins = 5
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(
    data = tips,
    x = 'total_bill',
    bins = 20

)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## 1.2 Kde

# %% [markdown]
# What is KDE?
#
# KDE = Kernel Density Estimation
#
# KDE is a smooth estimate of the data distribution.

# %% [markdown]
# A KDE curve makes it easier to see:
#
# - Where most values are concentrated.
# - Whether the data is symmetric.
# - Whether it's left-skewed or right-skewed.
# - Whether there are multiple peaks.

# %% [markdown]
#  KDE stands for Kernel Density Estimation.
#
# - It draws a smooth curve over the histogram.
# - It helps understand the shape of the distribution.
# - kde=True adds the density curve.
# - It does not change the data or the histogram.

# %%
"Example 1"

sns.histplot(
    data = tips,
    x = 'total_bill',
    kde = True
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## 1.3 hue

# %% [markdown]
# Used to divide the histogram into categories.
#
# - Requires a categorical column.
# - Helps compare distributions of different groups.
#
# Example:
# ```
#   hue="sex"
#   hue="smoker"
# ```

# %%
sns.histplot(
    data = tips,
    x = 'total_bill',
    hue = 'day',
    bins = 10
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(
    data = tips,
    x = 'total_bill',
    hue = 'sex'
    
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## 1.4 multiple

# %% [markdown]
# • Controls how histograms with hue are displayed.
#
# Types:
#
# 1. layer → Overlapping histograms (default)
# 2. dodge → Side-by-side histograms
# 3. stack → Stacked histograms
# 4. fill → Shows proportions (100%)

# %%
"Example 1"

sns.histplot(
    data = tips,
    x = 'total_bill',
    hue = 'sex',
    multiple = 'dodge'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
"Example 1"

sns.histplot(
    data = tips,
    x = 'total_bill',
    hue = 'sex',
    multiple = 'dodge',
    kde = True
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ## 1.5 stat

# %% [markdown]
# Controls what is shown on the Y-axis.
#
# count        → Number of observations (default)
#
# probability  → Probability (0 to 1)
#
# percent      → Percentage (0 to 100%)
#
# density      → Normalized density (commonly used with KDE)

# %%
"Example 1"

sns.histplot(
    data = tips,
    x = 'total_bill',
   stat = 'percent'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Percent'>

# %%
"Example 2"

sns.histplot(
    data = tips,
    x = 'total_bill',
   stat = 'probability'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Probability'>

# %% [markdown]
# # 2. Kdeplot

# %% [markdown]
# - histplot(kde=True) = Histogram + KDE curve.
# - kdeplot() = Only the KDE curve.

# %% [markdown]
# - Shows a smooth estimate of the data distribution.
# - Does not display histogram bars.
# - Helps understand the shape of the distribution.
# - Useful for identifying skewness and peaks.

# %% [markdown]
# ```
# Why use KDEPlot?
#
# Suppose you want to answer:
#
# Is the data normally distributed?
# Is it right-skewed?
# Is it left-skewed?
# Does it have two peaks?
# ```

# %%
"Example 1"

sns.kdeplot(
    data = tips,
    x ='total_bill'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## 2.1 hue

# %% [markdown]
# - Splits the KDE curve into categories.
# - Uses a categorical column.
# - Helps compare the distributions of different groups.

# %%
sns.kdeplot(
    data = tips,
    x = 'total_bill',
    hue = 'sex'
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ## 2.2 fill

# %% [markdown]
# - Fills the area under the KDE curve.
# - Makes the distribution easier to visualize.
# - Commonly used with hue for comparing groups.

# %%
sns.kdeplot(
    data = tips,
    x = 'total_bill',
    hue = 'sex',
    fill = True
)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # 3. distplot

# %% [markdown]
# It decides which plot to create based on the kind parameter.
#
# - sns.displot(..., kind="hist")
# - sns.displot(..., kind="kde")
# - sns.displot(..., kind="ecdf")
#
# So one function can generate multiple distribution plots.

# %% [markdown]
# - Figure-level function.
# - Used to visualize numerical distributions.
# - Can create different distribution plots.
# - Main parameter: kind
#
# kind="hist" → Histogram (default)
#
# kind="kde" → KDE Plot
#
# kind="ecdf" → ECDF Plot

# %%
"Example 1"


import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.displot(
    data=tips,
    x="total_bill"
)

plt.show()

# %%
"Example 2"

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.displot(
    data=tips,
    x="total_bill",
    kind ='kde' 
)

plt.show()

# %%
"Example 3"


import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.displot(
    data=tips,
    x="total_bill",
    kind = 'ecdf'
)

plt.show()

# %% [markdown]
# ## 3.1 axes level and figure level

# %% [markdown]
# ```
# 1. histplot() is an axes-level function that creates a histogram using bars (bins) to show the distribution of numerical data.
#
# 2. kdeplot() is an axes-level function that creates a smooth density curve to visualize the distribution without using bars.
#
# 3. displot() is a figure-level function that acts as a wrapper. It can create different distribution plots such as histograms and KDE plots using the kind parameter.
# ```

# %% [markdown]
# Axes-level
# ↓
#
# "Just draw a graph."
#
# - histplot()
# - kdeplot()
# - scatterplot()
#
# ----------------------------
#
# Figure-level
# ↓
#
# "Create the figure first,
# then draw graph(s)."
#
# - displot()
# - relplot()
# - catplot()
