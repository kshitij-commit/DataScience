# %% [markdown]
# ```
# Why do we need Categorical Plots?
#
# So far we've studied:
#
# Scatterplot → Relationship
# Lineplot → Trend
#
# But what if our x-axis contains categories like:
#
# Male
# Female
#
# or
#
# Smoker
# Non-Smoker
#
# or
#
# Sunday
# Monday
# Tuesday
#
# There is no relationship and no trend.
#
# Instead, we want to know:
#
# How many males?
# How many females?
# Which category has the highest count?
#
# For this, Seaborn provides Categorical Plots.
# ```

# %% [markdown]
# # Topic 1: countplot()

# %% [markdown]
# countplot() → Displays the count (frequency) of each category.

# %% [markdown]
#  Used for categorical data.
# - Counts the number of observations in each category.
# - Creates bars automatically.
# - No need to calculate counts manually.

# %% [markdown]
# ```
# Syntax
# sns.countplot(
#     data=df,
#     x='column_name'
# )
# ```

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.countplot(
    data = tips,
    x = 'sex'
              )

plt.show()

# %%
sns.countplot(
    data=tips,
    x = 'day'
)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# ## hue

# %% [markdown]
# hue in countplot()
#
# - Splits each category into subcategories.
# - Uses different colors for each subcategory.
# - Automatically creates a legend.

# %%
"Example 1"

# %%
sns.countplot(
    data = tips,
    x ='sex',
    hue = 'smoker'
)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## order

# %% [markdown]
# - Controls the order of categories.
# - Accepts a list.
# - Useful when default ordering is not suitable.

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.countplot(
    data = tips,
    x = 'day',
    order=['Mon', 'Sun', 'Thur', 'Fri', 'Sat']

)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(
    data = tips,
    x ='sex',
    order=['Male', 'Female']
)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Topic 2: barplot()

# %% [markdown]
# barplot() → Used to compare the average (or another aggregated value) of a numerical variable across different categories.

# %% [markdown]
# Calculates an aggregated numerical value (default = mean)

# %% [markdown]
# - Used to compare average numerical values across categories.
# - x → Categorical column
# - y → Numerical column
# - Default estimator = mean()
# - Height of each bar = average value.

# %%
sns.barplot(
    data = tips,
    x = 'sex',
    y = 'tip'
)
plt.show()

# %% [markdown]
# ## estimator

# %%
sns.barplot(
    data = tips,
    x = 'sex',
    y = 'tip',
    estimator='median'
)
plt.show()

# %% [markdown]
# ## hue

# %% [markdown]
# Splits each category into subcategories.
#
# - Calculates the average (default estimator) for each subcategory.
# - Different colors represent different subcategories.
# - Creates the legend automatically.

# %%
sns.barplot(
    data = tips,
    x = 'day',
    y = 'tip',
    hue = 'sex'
)

plt.show()

# %% [markdown]
# ## palette

# %% [markdown]
# palette → Changes the color theme of the bars.

# %% [markdown]
# palette
#
# - Changes the color theme.
# - Mostly used with hue.
# - Common palettes:
#   1. deep
#   2. Set2
#   3. colorblind
#   4. viridis

# %%
sns.barplot(
    data = tips,
    x = 'day',
    y = 'tip',
    hue = 'smoker',
    palette='Set1'
)
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ## order

# %% [markdown]
# - Controls the order of categories.
# - Accepts a list.

# %%
sns.barplot(
    data = tips,
    x = 'day',
    y = 'tip',
    order = ['Sun', 'Thur', 'Fri', 'Sat']
)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Topic: Boxplot

# %% [markdown]
# boxplot() → Used to visualize the distribution of a numerical variable across different categories using the five-number summary.

# %% [markdown]
#  Compares the distribution of numerical data across categories.
#
# • Shows:
#   1. Minimum
#   2. Q1
#   3. Median
#   4. Q3
#   5. Maximum
#   6. Outliers
# - x → Categorical column
# - y → Numerical column

# %% [markdown]
# ```
# Syntax
# sns.boxplot(
#     data=df,
#     x='Category',
#     y='Numerical Column'
# )
# ```

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.boxplot(
    data = tips,
    x = 'day',
    y = 'total_bill'
)
plt.show()

# %% [markdown]
# ## hue

# %% [markdown]
# - Splits each category into subcategories.
# - Draws a separate boxplot for each subcategory.
# - Helps compare distributions between subcategories.
# - Creates the legend automatically.

# %%
sns.boxplot(
    data = tips,
    x = 'day',
    y = 'total_bill',
    hue = 'sex'

)
plt.show()

# %% [markdown]
# ## palette

# %% [markdown]
# - Changes the color theme.
# - Mostly used with hue.
# - Does not change the data.

# %%
sns.boxplot(
    data=tips,
    x='day',
    y='total_bill',
    palette='Set2'
)
# Out:
# C:\Users\kshit\AppData\Local\Temp\ipykernel_3684\643112865.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(
    data=tips,
    x='day',
    y='total_bill',
    hue='sex',
    palette='colorblind'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Topic:  Violinplot

# %% [markdown]
# - Used to compare the distribution of numerical data across categories.
# - Shows everything a boxplot shows.
# - Also displays the density (shape) of the distribution.

# %% [markdown]
# - Shows distribution across categories.
# - Includes boxplot information.
# - Also shows density (shape) of the distribution.
# - Wider section → More observations.
# - Narrower section → Fewer observations.

# %% [markdown]
# The wider the violin,
#
# ➡️ the more data points are concentrated there.
#
# The narrower the violin,
#
# ➡️ the fewer data points are there.

# %%
sns.violinplot(
    data = tips,
    x = 'sex',
    y = 'tip'
)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(
    data=tips,
    x='sex',
    y='tip'
)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ## hue

# %% [markdown]
# - Splits categories into subcategories.
# - Draws a separate violinplot for each subcategory.
# - Helps compare density/distribution between subcategories.

# %%
sns.violinplot(
    data = tips,
    x = 'sex',
    y = 'tip',
    hue = 'day'

)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# ## palette

# %%
sns.violinplot(
    data = tips,
    x = 'day',
    y = 'tip',
    palette='Set2'
)
# Out:
# C:\Users\kshit\AppData\Local\Temp\ipykernel_3684\2845808205.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ## Order

# %%
sns.violinplot(
    data=tips,
    x='day',
    y='total_bill',
    order=['Thur', 'Fri', 'Sat', 'Sun']
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Topic: Stripplot

# %% [markdown]
# - Shows every individual data point.
# - Used to visualize the distribution of observations across categories.
# - Useful for small to medium-sized datasets.
# - x → Categorical column
# - y → Numerical column
# - Each dot represents one observation.

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
'Example 1'

sns.stripplot(
    data=tips,
    x = 'day',
    y = 'total_bill'
   
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ```
# 👉 Every dot is one observation (one row in the dataset).
# ```

# %% [markdown]
# # Topic: swarmplot

# %% [markdown]
# - Shows every individual observation.
# - Automatically adjusts point positions to avoid overlap.
# - Better than stripplot for dense datasets.

# %% [markdown]
# ```
# Example
#
# stripplot()
#    •
#    •
#    •
#    •
#
# Points overlap.
#
# swarmplot()
#  • •
# • • •
#  • •
#
# The points are shifted sideways so that every point is visible.
# ```

# %% [markdown]
#  Shows every individual observation.
#
# - Prevents overlapping points.
# - Best for small to medium datasets.
# - x → Categorical
# - y → Numerical

# %%
"Example 1"

sns.swarmplot(
    data = tips,
    x = 'day',
    y = 'total_bill'
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
